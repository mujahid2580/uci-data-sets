# %%
import pandas as pd

# %%
no=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00267/data_banknote_authentication.txt",header=None)
no
# Out:
#             0         1        2        3  4
# 0     3.62160   8.66610  -2.8073 -0.44699  0
# 1     4.54590   8.16740  -2.4586 -1.46210  0
# 2     3.86600  -2.63830   1.9242  0.10645  0
# 3     3.45660   9.52280  -4.0112 -3.59440  0
# 4     0.32924  -4.45520   4.5718 -0.98880  0
# ...       ...       ...      ...      ... ..
# 1367  0.40614   1.34920  -1.4501 -0.55949  1
# 1368 -1.38870  -4.87730   6.4774  0.34179  1
# 1369 -3.75030 -13.45860  17.5932 -2.77710  1
# 1370 -3.56370  -8.38270  12.3930 -1.28230  1
# 1371 -2.54190  -0.65804   2.6842  1.19520  1
#
# [1372 rows x 5 columns]

# %%
name = [["1. variance of Wavelet Transformed image","skewness of Wavelet Transformed image","curtosis of Wavelet Transformed image","entropy of image","class"]]
no.columns = name

# %%
no
# Out:
#      1. variance of Wavelet Transformed image  \
# 0                                     3.62160
# 1                                     4.54590
# 2                                     3.86600
# 3                                     3.45660
# 4                                     0.32924
# ...                                       ...
# 1367                                  0.40614
# 1368                                 -1.38870
# 1369                                 -3.75030
# 1370                                 -3.56370
# 1371                                 -2.54190
#
#      skewness of Wavelet Transformed image  \
# 0                                  8.66610
# 1                                  8.16740
# 2                                 -2.63830
# 3                                  9.52280
# 4                                 -4.45520
# ...                                    ...
# 1367                               1.34920
# 1368                              -4.87730
# ...

# %%
no.to_csv("Banknote.csv")
