# %%
import pandas as pd

# %%
n=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/00451/dataR2.csv",header=None)
n
# Out:
#        0            1        2        3            4        5            6  \
# 0    Age          BMI  Glucose  Insulin         HOMA   Leptin  Adiponectin
# 1     48         23.5       70    2.707  0.467408667   8.8071       9.7024
# 2     83  20.69049454       92    3.115  0.706897333   8.8438     5.429285
# 3     82  23.12467037       91    4.498  1.009651067  17.9393     22.43204
# 4     68  21.36752137       77    3.226  0.612724933   9.8827      7.16956
# ..   ...          ...      ...      ...          ...      ...          ...
# 112   45        26.85       92     3.33     0.755688    54.68         12.1
# 113   62        26.84      100     4.53       1.1174    12.45        21.42
# 114   65        32.05       97     5.73     1.370998    61.48        22.54
# 115   72        25.59       82     2.82     0.570392    24.96        33.75
# 116   86        27.18      138    19.91     6.777364    90.28        14.11
#
#             7        8               9
# ...

# %%
n.to_csv("Breast cancer caimbra.csv")
