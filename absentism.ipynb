# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\absentism 1.csv",header=None)
df
# Out:
#      0                   1                 2                3        4   \
# 0    ID  Reason for absence  Month of absence  Day of the week  Seasons
# 1    11                  26                 7                3        1
# 2    36                   0                 7                3        1
# 3     3                  23                 7                4        1
# 4     7                   7                 7                5        1
# ..   ..                 ...               ...              ...      ...
# 736  11                  14                 7                3        1
# 737   1                  11                 7                3        1
# 738   4                   0                 0                3        1
# 739   8                   0                 0                4        2
# 740  35                   0                 0                6        3
#
#                          5                                6             7   \
# ...

# %%
df.shape
# Out:
# (740, 21)

# %%
df.to_csv("absentism.csv")
