# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\audit_risk.csv",header=None)
df
# Out:
#                0            1       2        3       4       5        6   \
# 0    Sector_score  LOCATION_ID  PARA_A  Score_A  Risk_A  PARA_B  Score_B
# 1            3.89           23    4.18      0.6   2.508     2.5      0.2
# 2            3.89            6       0      0.2       0    4.83      0.2
# 3            3.89            6    0.51      0.2   0.102    0.23      0.2
# 4            3.89            6       0      0.2       0    10.8      0.6
# ..            ...          ...     ...      ...     ...     ...      ...
# 772         55.57            9    0.49      0.2   0.098     0.4      0.2
# 773         55.57           16    0.47      0.2   0.094    0.37      0.2
# 774         55.57           14    0.24      0.2   0.048    0.04      0.2
# 775         55.57           18     0.2      0.2    0.04       0      0.2
# 776         55.57           15       0      0.2       0       0      0.2
#
#          7      8        9   ...      17       18    19      20     21  \
# ...

# %%
df.to_csv("audit_risk.csv")
