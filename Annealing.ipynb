# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/mujahid2580/Regression-Data-sets/master/annealing.csv")

# %%
data
# Out:
#      Unnamed: 0 family product steel  carbon  hardness temper_rolling  \
# 0             0      ?       C     A       8         0              ?
# 1             1      ?       C     R       0         0              ?
# 2             2      ?       C     R       0         0              ?
# 3             3      ?       C     A       0        60              T
# 4             4      ?       C     A       0        60              T
# ..          ...    ...     ...   ...     ...       ...            ...
# 793         793      ?       C     A       0        50              T
# 794         794      ?       C     ?       0         0              ?
# 795         795      ?       C     A       0         0              ?
# 796         796      ?       C     A       0         0              ?
# 797         797      ?       C     R       0         0              ?
#
#     condition formability  strength  ...  s  p  shape  thick   width   len  \
# ...

# %%
del data["Unnamed: 0"]

# %%
data
# Out:
#     family product steel  carbon  hardness temper_rolling condition  \
# 0        ?       C     A       8         0              ?         S
# 1        ?       C     R       0         0              ?         S
# 2        ?       C     R       0         0              ?         S
# 3        ?       C     A       0        60              T         ?
# 4        ?       C     A       0        60              T         ?
# ..     ...     ...   ...     ...       ...            ...       ...
# 793      ?       C     A       0        50              T         ?
# 794      ?       C     ?       0         0              ?         S
# 795      ?       C     A       0         0              ?         S
# 796      ?       C     A       0         0              ?         S
# 797      ?       C     R       0         0              ?         S
#
#     formability  strength non-ageing  ...  s  p  shape  thick   width   len  \
# ...

# %%
data.to_csv("annealing.csv")
