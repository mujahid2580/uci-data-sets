# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\LENOVO\Desktop\Frogs_MFCCs.csv",header=None)
df
# Out:
#             0             1             2            3            4   \
# 0     MFCCs_ 1      MFCCs_ 2      MFCCs_ 3     MFCCs_ 4     MFCCs_ 5
# 1            1   0.152936298  -0.105585903  0.200721915  0.317201062
# 2            1   0.171534257  -0.098974737  0.268425221  0.338671863
# 3            1   0.152317085  -0.082972674  0.287127957  0.276014084
# 4            1   0.224392446   0.118984664  0.329431729   0.37208801
# ...        ...           ...           ...          ...          ...
# 7191         1  -0.554504037  -0.337716711  0.035533459  0.034511324
# 7192         1  -0.517273069  -0.370573645  0.030673195  0.068096966
# 7193         1  -0.582556781  -0.343237394  0.029467847  0.064179463
# 7194         1  -0.519497158   -0.30755306   -0.0049215   0.07286539
# 7195         1  -0.508833178  -0.324105837  0.062067624  0.078211153
#
#                5            6             7             8            9   ...  \
# ...

# %%
df.to_csv("Frogs_MFCCs.csv")
