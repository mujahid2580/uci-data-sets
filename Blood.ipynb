# %%
import pandas as pd

# %%
l=pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/blood-transfusion/transfusion.data",header=None)
l
# Out:
#                     0                  1                      2  \
# 0    Recency (months)  Frequency (times)  Monetary (c.c. blood)
# 1                  2                  50                  12500
# 2                  0                  13                   3250
# 3                  1                  16                   4000
# 4                  2                  20                   5000
# ..                ...                ...                    ...
# 744               23                   2                    500
# 745               21                   2                    500
# 746               23                   3                    750
# 747               39                   1                    250
# 748               72                   1                    250
#
#                  3                                           4
# 0    Time (months)  whether he/she donated blood in March 2007
# 1              98                                            1
# ...

# %%
l.to_csv("Blood data.csv")
